# %%
import os, datetime

# Working directory
directory = '/Users/kelvin/Downloads/【毛泽东“南方决策”】有声小说在线收听_喜马拉雅FM'
os.chdir(directory)
# extensions for files that we want rename
extensions = (['.m4a']);

# Get a list of files in the directory
filelist = os.listdir( directory )

# count the number of files that are renamed
count = 0
files = sorted(filelist,key=os.path.getmtime,reverse=False)
n=0
for f in files:
    n+=1
    print(str(n)+'_'+f)
    os.rename( f, str(n)+'_'+f);

print( 'All done. ' + str(count) + ' files are renamed. ')
# Out:
# 1_00引子.m4a
# 2_01第一章 老一代革命家奋起“二月抗争”.m4a
# 3_02第二章 林彪集团达到鼎盛.m4a
# 4_03第三章 从井冈山到毛家湾1.m4a
# 5_04第三章 从井冈山到毛家湾2.m4a
# 6_05第四章 林彪集团图谋不轨.m4a
# 7_06第五章 “跃上葱茏四百旋”.m4a
# 8_07第六章 《我的一点意见》影响巨大.m4a
# 9_08第七章 “天才问题”、“设国家主席问题”.m4a
# 10_09第八章“庐山是炸不平的，地球还是照样转”.m4a
# 11_10第九章 毛泽东“甩石头”，“掺沙子”，“挖墙脚”.m4a
# 12_11第十章 改组北京军区，任命新的司令员和政治委员.m4a
# 13_12第十一章 林彪集团拟定武装计划1.m4a
# 14_13第十一章 林彪集团拟定武装计划2.m4a
# 15_14第十二章 毛泽东频频发表南巡谈话1.m4a
# 16_15第十二章 毛泽东频频发表南巡谈话2.m4a
# 17_16第十三章 会见南方党政军高级干部（上）.m4a
# 18_17第十四章 会见南方党政军高级干部（下）.m4a
# 19_18第十五章 “从来就没有什么救世主”1.m4a
# 20_19第十五章 “从来就没有什么救世主”2.m4a
# 21_20第十六章 林彪集团刺探毛泽东南巡情况.m4a
# 22_21第十七章 林立果等密谋刺杀毛泽东.m4a
# 23_22第十八章 “怎样发现林彪集团搞活动的？”1.m4a
# 24_23第十八章 “怎样发现林彪集团搞活动的？”2.m4a
# 25_24第十九章 林彪集团策划“南逃广州，另立中央”（上）.m4a
# 26_25第二十章 林彪集团策划“南逃广州，另立中央”（下）.m4a
# 27_26第二十一章 “月黑雁飞高，林彪夜遁逃”.m4a
# 28_27第二十二章 周恩来命令：任何飞机不得起飞，全国“禁空”.m4a
# 29_28第二十三章 空军司令部作战部原部长的亲历1.m4a
# 30_29第二十三章 空军司令部作战部原部长的亲历2.m4a
# 31_30第二十四章 周恩来驾驭全局，指挥若定.m4a
# 32_31第二十五章 “林彪外逃，机毁人亡是最好的结局”.m4a
# 33_32第二十六章 中共中央命令：逮捕王维国、陈励耘1.m4a
# 34_33第二十六章 中共中央命令：逮捕王维国、陈励耘2.m4a
# 35_34第二十七章 清查林彪集团策划武装的来龙去脉.m4a
# 36_35第二十八章 周恩来痛哭失声.m4a
# 37_36第二十九章 “折戟沉沙铁未销，蒙古大火烧林彪”.m4a
# 38_37第三十章 中国大使应对“中国政治之谜”.m4a
# 39_38第三十一章 周恩来澄清林彪外逃真相1.m4a
# 40_39第三十一章 周恩来澄清林彪外逃真相2.m4a
# 41_40第三十二章 中央军委对林彪的最新评价.m4a
# 42_01第一章 “他在中央苏区是挨整的是所谓毛派的头子”.m4a
# 43_02第二章 恢复邓小平国务院副总理职务.m4a
# 44_03第三章 中共十大：筹备与召开内情.m4a
# 45_04第四章 毛泽东确立新的接班人.m4a
# 46_05第五章 一个“流氓无产者”的发迹史（上）.m4a
# 47_06第六章 一个“流氓无产者”的发迹史（下）.m4a
# 48_07第七章 邓小平再次脱颖而出1.m4a
# 49_08第七章 邓小平再次脱颖而出2.m4a
# 50_09第八章 邓小平任中共中央政治局委员、中央军委委员1.m4a
# 51_10第八章 邓小平任中共中央政治局委员、中央军委委员2.m4a
# 52_11第九章 集团制造新的内乱1.m4a
# 53_12第九章 集团制造新的内乱2.m4a
# 54_13第十章 一场确定“中国代表团团长”的斗争1.m4a
# 55_14第十章 一场确定“中国代表团团长”的斗争2.m4a
# 56_15第十一章 中国领导人首次在联合国发言.m4a
# 57_16第十二章 毛泽东指着说：她算“上海帮”呢.m4a
# 58_17第十三章 毛泽东回到家乡养病1.m4a
# 59_18第十三章 毛泽东回到家乡养病2.m4a
# 60_19第十四章 领袖与机要秘书1.m4a
# 61_20第十四章 领袖与机要秘书2.m4a
# 62_21第十五章 “为什么要批判《园丁之歌》？”.m4a
# 63_22第十六章 “主席看了这出戏，主席说是好戏”.m4a
# 64_23第十七章 历史巨人的晚年心态1.m4a
# 65_24第十七章 历史巨人的晚年心态2.m4a
# 66_25第十八章 “”密谋“长沙告状”.m4a
# 67_26第十九章 “邓小平任第一副总理兼总参谋长”.m4a
# 68_27第二十章 周恩来抱病飞往长沙.m4a
# 69_28第二十一章 决定中国命运的重大决策1.m4a
# 70_29第二十一章 决定中国命运的重大决策2.m4a
# 71_30第二十二章 “南方决策”得到圆满实现1.m4a
# 72_31第二十二章 “南方决策”得到圆满实现2.m4a
# 73_32第二十三章 “代总理主持会议和呈批主要文件”.m4a
# 74_33第二十四章 “远交近攻”，会见西方政治家.m4a
# 75_34第二十五章 “调动一个团，把从杭州饭店赶出去”.m4a
# 76_35第二十六章 中央政治局会议批评.m4a
# 77_36第二十七章 毛泽东主持中央政治局会议.m4a
# 78_37第二十八章 邓小平主持中央日常工作1.m4a
# 79_38第二十八章 邓小平主持中央日常工作2.m4a
# All done. 0 files are renamed.
